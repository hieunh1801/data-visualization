# %%
# %matplotlib inline
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
# Step 1: Read File
df = pd.read_excel('datasets/data.xlsx', sheetname='Sheet1')
print(df) 
df.plot.bar(x='Domain', y=['Consumer', 'Producer'])
# Out:
#                    Domain  Producer  Consumer
# 0                      IT      1.96      0.40
# 1          Bussiness User      4.25      0.75
# 2              Power User      3.50     21.50
# 3             Casual User      1.50     28.50
# 4  Extend Enterprise User      0.76     37.24
